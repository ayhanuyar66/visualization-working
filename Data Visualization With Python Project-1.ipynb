# %% [markdown]
# # <p style="background-color:green;font-family:newtimeroman;font-size:200%;color:white;text-align:center;border-radius:20px 20px;"><b>EDA & Data Visualization Project</b></p>
# ![](https://www.techproeducation.com/logo/headerlogo.svg)
#
# <b>Yeniliklerden ilk siz haberdar olmak istiyorsanız lütfen bizi takip etmeyi unutmayın </b>[YouTube](https://www.youtube.com/c/techproeducation) | [Instagram](https://www.instagram.com/techproeducation) | [Facebook](https://www.facebook.com/techproeducation) | [Telegram](https://t.me/joinchat/HH2qRvA-ulh4OWbb) | [Whatsapp](https://api.whatsapp.com/send/?phone=%2B15853042959&text&type=phone_number&app_absent=0) | [Linkedin](https://www.linkedin.com/company/techproeducation/mycompany/) |

# %% [markdown]
# <div class="alert alert-block alert-info alert">
#
# # <span style=" color:red">WELCOME!
#
# Welcome to "Bike Demand Visualization Project" which is the capstone project of Data Visualization Lessons . As you know recently, free or affordable access to bicycles has been provided for short-distance trips in an urban area as an alternative to motorized public transport or private vehicles. Thus, it is aimed to reduce traffic congestion, noise and air pollution.
#
# The aim of this project is to reveal the current patterns in the data by showing the historical data of London bike shares with visualization tools.
#
# This will allow us to X-ray the data as part of the EDA process before setting up a machine learning model.</span>

# %% [markdown]
# <div class="alert alert-block alert-success ">
#
# ## <span style=" color:red">Determines
#
# Features
#
# - timestamp - timestamp field for grouping the data
# - cnt - the count of a new bike shares
# - t1 - real temperature in C
# - t2 - temperature in C “feels like”
# - hum - humidity in percentage
# - wind_speed - wind speed in km/h
# - weather_code - category of the weather
# - is_holiday - boolean field - 1 holiday / 0 non holiday
# - is_weekend - boolean field - 1 if the day is weekend
# - season - category field meteorological seasons: 0-spring ; 1-summer; 2-fall; 3-winter.
#
# "weather_code" category description:
#
# - 1 = Clear ; mostly clear but have some values with haze/fog/patches of fog/ fog in vicinity
# - 2 = scattered clouds / few clouds
# - 3 = Broken clouds
# - 4 = Cloudy
# - 7 = Rain/ light Rain shower/ Light rain
# - 10 = rain with thunderstorm
# - 26 = snowfall
# - 94 = Freezing Fog
#
# Initially, the task of discovering data will be waiting for you as always. Recognize features, detect missing values, outliers etc. Review the data from various angles in different time breakdowns. For example, visualize the distribution of bike shares by day of the week. With this graph, you will be able to easily observe and make inferences how people's behavior changes daily. Likewise, you can make hourly, monthly, seasonally etc. analyzes. In addition, you can analyze correlation of variables with a heatmap.
#
# # <span style=" color:red">Tasks
# </span>

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">1. Import Libraries
# </span>

# %%
import pandas as pd

import numpy as np

#import matplotlib as mpl
import matplotlib.pyplot as plt

import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">2. Read Dataset
# </span>

# %%
df = pd.read_csv("store_sharing.csv")
df
# Out:
#                  timestamp   cnt   t1   t2    hum  wind_speed  weather_code  \
# 0      2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0           3.0
# 1      2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0           1.0
# 2      2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0           1.0
# 3      2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0           1.0
# 4      2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5           1.0
# ...                    ...   ...  ...  ...    ...         ...           ...
# 17409  2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0           3.0
# 17410  2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0           4.0
# 17411  2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0           4.0
# 17412  2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0           4.0
# 17413  2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0           2.0
#
#        is_holiday  is_weekend  season
# 0             0.0         1.0     3.0
# 1             0.0         1.0     3.0
# 2             0.0         1.0     3.0
# 3             0.0         1.0     3.0
# 4             0.0         1.0     3.0
# ...           ...         ...     ...
# 17409         0.0         0.0     3.0
# 17410         0.0         0.0     3.0
# 17411         0.0         0.0     3.0
# 17412         0.0         0.0     3.0
# 17413         0.0         0.0     3.0
#
# [17414 rows x 10 columns]

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">3. Check missing values and if there are any dublicate rows or not.
# </span>

# %%
df.info() #no null
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  object
#  1   cnt           17414 non-null  int64
#  2   t1            17414 non-null  float64
#  3   t2            17414 non-null  float64
#  4   hum           17414 non-null  float64
#  5   wind_speed    17414 non-null  float64
#  6   weather_code  17414 non-null  float64
#  7   is_holiday    17414 non-null  float64
#  8   is_weekend    17414 non-null  float64
#  9   season        17414 non-null  float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 1.3+ MB

# %%
df.drop_duplicates()
# Out:
#                  timestamp   cnt   t1   t2    hum  wind_speed  weather_code  \
# 0      2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0           3.0
# 1      2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0           1.0
# 2      2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0           1.0
# 3      2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0           1.0
# 4      2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5           1.0
# ...                    ...   ...  ...  ...    ...         ...           ...
# 17409  2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0           3.0
# 17410  2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0           4.0
# 17411  2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0           4.0
# 17412  2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0           4.0
# 17413  2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0           2.0
#
#        is_holiday  is_weekend  season
# 0             0.0         1.0     3.0
# 1             0.0         1.0     3.0
# 2             0.0         1.0     3.0
# 3             0.0         1.0     3.0
# 4             0.0         1.0     3.0
# ...           ...         ...     ...
# 17409         0.0         0.0     3.0
# 17410         0.0         0.0     3.0
# 17411         0.0         0.0     3.0
# 17412         0.0         0.0     3.0
# 17413         0.0         0.0     3.0
#
# [17414 rows x 10 columns]

# %%
df.isna().sum()
# Out:
# timestamp       0
# cnt             0
# t1              0
# t2              0
# hum             0
# wind_speed      0
# weather_code    0
# is_holiday      0
# is_weekend      0
# season          0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# timestamp       17414
# cnt             17414
# t1              17414
# t2              17414
# hum             17414
# wind_speed      17414
# weather_code    17414
# is_holiday      17414
# is_weekend      17414
# season          17414
# dtype: int64

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">4. Plot the distribution of various discrete features on (Season, holiday, weekend and weathercode)
# </span>

# %%
sns.displot(x= "season", data = df, kde= True)

# %%
df
# Out:
#                  timestamp   cnt   t1   t2    hum  wind_speed  weather_code  \
# 0      2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0           3.0
# 1      2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0           1.0
# 2      2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0           1.0
# 3      2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0           1.0
# 4      2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5           1.0
# ...                    ...   ...  ...  ...    ...         ...           ...
# 17409  2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0           3.0
# 17410  2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0           4.0
# 17411  2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0           4.0
# 17412  2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0           4.0
# 17413  2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0           2.0
#
#        is_holiday  is_weekend  season
# 0             0.0         1.0     3.0
# 1             0.0         1.0     3.0
# 2             0.0         1.0     3.0
# 3             0.0         1.0     3.0
# 4             0.0         1.0     3.0
# ...           ...         ...     ...
# 17409         0.0         0.0     3.0
# 17410         0.0         0.0     3.0
# 17411         0.0         0.0     3.0
# 17412         0.0         0.0     3.0
# 17413         0.0         0.0     3.0
#
# [17414 rows x 10 columns]

# %%
sns.histplot(x='is_weekend',data=df,kde = True)
# Out:
# <Axes: xlabel='is_weekend', ylabel='Count'>

# %%
sns.rugplot(x='weather_code',data=df, height = 0.8);

# %%
sns.kdeplot(x ="is_holiday",data= df)
# Out:
# <Axes: xlabel='is_holiday', ylabel='Density'>

# %% [markdown]
# # weather_code
# sns.countplot(x='weather_code',data=df)
#
# 1 = Clear ; mostly clear but have some values with haze/fog/patches of fog/ fog in vicinity
# 2 = scattered clouds / few clouds
# 3 = Broken clouds
# 4 = Cloudy
# 7 = Rain/ light Rain shower/ Light rain
# 10 = rain with thunderstorm
# 26 = snowfall
# 94 = Freezing Fog

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">5. Look at the data type of each variable, transform timestamp in type, and set it as index.
# </span>

# %%
df.dtypes
# Out:
# timestamp        object
# cnt               int64
# t1              float64
# t2              float64
# hum             float64
# wind_speed      float64
# weather_code    float64
# is_holiday      float64
# is_weekend      float64
# season          float64
# dtype: object

# %%
df
# Out:
#                  timestamp   cnt   t1   t2    hum  wind_speed  weather_code  \
# 0      2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0           3.0
# 1      2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0           1.0
# 2      2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0           1.0
# 3      2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0           1.0
# 4      2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5           1.0
# ...                    ...   ...  ...  ...    ...         ...           ...
# 17409  2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0           3.0
# 17410  2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0           4.0
# 17411  2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0           4.0
# 17412  2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0           4.0
# 17413  2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0           2.0
#
#        is_holiday  is_weekend  season
# 0             0.0         1.0     3.0
# 1             0.0         1.0     3.0
# 2             0.0         1.0     3.0
# 3             0.0         1.0     3.0
# 4             0.0         1.0     3.0
# ...           ...         ...     ...
# 17409         0.0         0.0     3.0
# 17410         0.0         0.0     3.0
# 17411         0.0         0.0     3.0
# 17412         0.0         0.0     3.0
# 17413         0.0         0.0     3.0
#
# [17414 rows x 10 columns]

# %%
df['timestamp'] = df['timestamp'].astype('datetime64[ns]')
df['timestamp']
# Out:
# 0       2015-01-04 00:00:00
# 1       2015-01-04 01:00:00
# 2       2015-01-04 02:00:00
# 3       2015-01-04 03:00:00
# 4       2015-01-04 04:00:00
#                 ...
# 17409   2017-01-03 19:00:00
# 17410   2017-01-03 20:00:00
# 17411   2017-01-03 21:00:00
# 17412   2017-01-03 22:00:00
# 17413   2017-01-03 23:00:00
# Name: timestamp, Length: 17414, dtype: datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  datetime64[ns]
#  1   cnt           17414 non-null  int64
#  2   t1            17414 non-null  float64
#  3   t2            17414 non-null  float64
#  4   hum           17414 non-null  float64
#  5   wind_speed    17414 non-null  float64
#  6   weather_code  17414 non-null  float64
#  7   is_holiday    17414 non-null  float64
#  8   is_weekend    17414 non-null  float64
#  9   season        17414 non-null  float64
# dtypes: datetime64[ns](1), float64(8), int64(1)
# memory usage: 1.3 MB

# %%
df.set_index('timestamp', inplace = True)

# %%
df
# Out:
#                       cnt   t1   t2    hum  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0           3.0
# 2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0           1.0
# 2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0           1.0
# 2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0           1.0
# 2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5           1.0
# ...                   ...  ...  ...    ...         ...           ...
# 2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0           3.0
# 2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0           4.0
# 2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0           4.0
# 2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0           4.0
# 2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0           2.0
#
#                      is_holiday  is_weekend  season
# timestamp
# 2015-01-04 00:00:00         0.0         1.0     3.0
# 2015-01-04 01:00:00         0.0         1.0     3.0
# 2015-01-04 02:00:00         0.0         1.0     3.0
# 2015-01-04 03:00:00         0.0         1.0     3.0
# 2015-01-04 04:00:00         0.0         1.0     3.0
# ...                         ...         ...     ...
# 2017-01-03 19:00:00         0.0         0.0     3.0
# 2017-01-03 20:00:00         0.0         0.0     3.0
# 2017-01-03 21:00:00         0.0         0.0     3.0
# 2017-01-03 22:00:00         0.0         0.0     3.0
# 2017-01-03 23:00:00         0.0         0.0     3.0
#
# [17414 rows x 9 columns]

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">6. Make feature engineering. Extract new columns (day of the week, day of the month, hour, month, season, year etc.)
# </span>

# %% [markdown]
# ![Screenshot%202021-10-27%20164721.png](attachment:Screenshot%202021-10-27%20164721.png)

# %%
df["year"] =  df.index.year
df["month"] =  df.index.month
df["day_of_month"] =  df.index.day
df["day_of_week"] =  df.index.dayofweek
df["hour"] = df.index.hour

df["year-month"] = df.index.strftime("%Y-%m")
df.head()
# Out:
#                      cnt   t1   t2    hum  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#                      is_holiday  is_weekend  season  year  month  \
# timestamp
# 2015-01-04 00:00:00         0.0         1.0     3.0  2015      1
# 2015-01-04 01:00:00         0.0         1.0     3.0  2015      1
# 2015-01-04 02:00:00         0.0         1.0     3.0  2015      1
# 2015-01-04 03:00:00         0.0         1.0     3.0  2015      1
# 2015-01-04 04:00:00         0.0         1.0     3.0  2015      1
#
#                      day_of_month  day_of_week  hour year-month
# timestamp
# 2015-01-04 00:00:00             4            6     0    2015-01
# 2015-01-04 01:00:00             4            6     1    2015-01
# 2015-01-04 02:00:00             4            6     2    2015-01
# 2015-01-04 03:00:00             4            6     3    2015-01
# 2015-01-04 04:00:00             4            6     4    2015-01

# %%
df
# Out:
#                       cnt   t1   t2    hum  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0           3.0
# 2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0           1.0
# 2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0           1.0
# 2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0           1.0
# 2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5           1.0
# ...                   ...  ...  ...    ...         ...           ...
# 2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0           3.0
# 2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0           4.0
# 2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0           4.0
# 2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0           4.0
# 2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0           2.0
#
#                      is_holiday  is_weekend  season  year  month  \
# timestamp
# 2015-01-04 00:00:00         0.0         1.0     3.0  2015      1
# 2015-01-04 01:00:00         0.0         1.0     3.0  2015      1
# 2015-01-04 02:00:00         0.0         1.0     3.0  2015      1
# 2015-01-04 03:00:00         0.0         1.0     3.0  2015      1
# 2015-01-04 04:00:00         0.0         1.0     3.0  2015      1
# ...                         ...         ...     ...   ...    ...
# 2017-01-03 19:00:00         0.0         0.0     3.0  2017      1
# 2017-01-03 20:00:00         0.0         0.0     3.0  2017      1
# 2017-01-03 21:00:00         0.0         0.0     3.0  2017      1
# 2017-01-03 22:00:00         0.0         0.0     3.0  2017      1
# 2017-01-03 23:00:00         0.0         0.0     3.0  2017      1
#
#                      day_of_month  day_of_week  hour year-month
# timestamp
# 2015-01-04 00:00:00             4            6     0    2015-01
# 2015-01-04 01:00:00             4            6     1    2015-01
# 2015-01-04 02:00:00             4            6     2    2015-01
# 2015-01-04 03:00:00             4            6     3    2015-01
# 2015-01-04 04:00:00             4            6     4    2015-01
# ...                           ...          ...   ...        ...
# 2017-01-03 19:00:00             3            1    19    2017-01
# 2017-01-03 20:00:00             3            1    20    2017-01
# 2017-01-03 21:00:00             3            1    21    2017-01
# 2017-01-03 22:00:00             3            1    22    2017-01
# 2017-01-03 23:00:00             3            1    23    2017-01
#
# [17414 rows x 15 columns]

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">7. Visualize the correlation with a heatmap
# </span>

# %%
df.drop('year-month',inplace = True,axis =1)

# %%
df.corr()
# Out:
#                    cnt        t1        t2       hum  wind_speed  \
# cnt           1.000000  0.388798  0.369035 -0.462901    0.116295
# t1            0.388798  1.000000  0.988344 -0.447781    0.145471
# t2            0.369035  0.988344  1.000000 -0.403495    0.088409
# hum          -0.462901 -0.447781 -0.403495  1.000000   -0.287789
# wind_speed    0.116295  0.145471  0.088409 -0.287789    1.000000
# weather_code -0.166633 -0.097114 -0.098385  0.334750    0.124803
# is_holiday   -0.051698 -0.042233 -0.040051  0.032068   -0.002606
# is_weekend   -0.096499 -0.005342 -0.008510  0.028098    0.011479
# season       -0.116180 -0.285851 -0.285900  0.290381    0.010305
# year          0.010046 -0.037959 -0.044972  0.072443   -0.094739
# month         0.063757  0.332712  0.368366  0.113149   -0.086383
# day_of_month -0.017887  0.005072  0.006791 -0.020868    0.002040
# day_of_week  -0.068688 -0.002317 -0.006824  0.011556    0.001708
# hour          0.324423  0.168708  0.153956 -0.295653    0.141792
#
#               weather_code  is_holiday  is_weekend    season      year  \
# cnt              -0.166633   -0.051698   -0.096499 -0.116180  0.010046
# t1               -0.097114   -0.042233   -0.005342 -0.285851 -0.037959
# t2               -0.098385   -0.040051   -0.008510 -0.285900 -0.044972
# hum               0.334750    0.032068    0.028098  0.290381  0.072443
# wind_speed        0.124803   -0.002606    0.011479  0.010305 -0.094739
# weather_code      1.000000    0.012939    0.042362  0.098976 -0.009234
# is_holiday        0.012939    1.000000   -0.094898 -0.032488  0.034631
# is_weekend        0.042362   -0.094898    1.000000  0.001067  0.003049
# season            0.098976   -0.032488    0.001067  1.000000  0.024400
# year             -0.009234    0.034631    0.003049  0.024400  1.000000
# month            -0.033253   -0.011511   -0.005406  0.203249 -0.026547
# day_of_month      0.001904    0.042657    0.005721 -0.006460 -0.021935
# day_of_week       0.020619   -0.144628    0.791975  0.002356 -0.002876
# hour             -0.041786   -0.000288    0.001803  0.000006  0.000542
#
#                  month  day_of_month  day_of_week      hour
# cnt           0.063757     -0.017887    -0.068688  0.324423
# t1            0.332712      0.005072    -0.002317  0.168708
# t2            0.368366      0.006791    -0.006824  0.153956
# hum           0.113149     -0.020868     0.011556 -0.295653
# wind_speed   -0.086383      0.002040     0.001708  0.141792
# weather_code -0.033253      0.001904     0.020619 -0.041786
# is_holiday   -0.011511      0.042657    -0.144628 -0.000288
# is_weekend   -0.005406      0.005721     0.791975  0.001803
# season        0.203249     -0.006460     0.002356  0.000006
# year         -0.026547     -0.021935    -0.002876  0.000542
# month         1.000000      0.012614    -0.001080 -0.000312
# day_of_month  0.012614      1.000000     0.006974 -0.000310
# day_of_week  -0.001080      0.006974     1.000000  0.001834
# hour         -0.000312     -0.000310     0.001834  1.000000

# %%
plt.figure(figsize = (16,12))
sns.heatmap(data=df.corr(),annot = True, cmap="viridis")
# Out:
# <Axes: >

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">8. Visualize the correlation of the target variable and the other features with barplot
# </span>

# %% [markdown]
# ![Screenshot%202021-10-27%20170237.png](attachment:Screenshot%202021-10-27%20170237.png)

# %%
df.corr()['cnt']
# Out:
# cnt             1.000000
# t1              0.388798
# t2              0.369035
# hum            -0.462901
# wind_speed      0.116295
# weather_code   -0.166633
# is_holiday     -0.051698
# is_weekend     -0.096499
# season         -0.116180
# year            0.010046
# month           0.063757
# day_of_month   -0.017887
# day_of_week    -0.068688
# hour            0.324423
# Name: cnt, dtype: float64

# %%
plt.figure(figsize=(10,6))

df.corr()[["cnt"]].sort_values(by="cnt").plot.barh()
# Out:
# <Axes: >

# %%
df_corr=df.corr()[["cnt"]].sort_values(by="cnt", ascending=False)

# %%
plt.figure(figsize=(2,7))
sns.heatmap(df_corr, annot=True, cmap="coolwarm", vmin=-1,vmax=1);

# %%
df_corr = df.corr()[["cnt"]].sort_values(by="cnt", ascending=False)


plt.figure(figsize=(16, 6))
sns.barplot(x=df_corr.index, y=df_corr["cnt"].values, palette="coolwarm")#
# Out:
# <Axes: xlabel='None'>

# %%
df_corr = df.corr()[["cnt"]].sort_values(by="cnt", ascending=False)
df_corr
# Out:
#                    cnt
# cnt           1.000000
# t1            0.388798
# t2            0.369035
# hour          0.324423
# wind_speed    0.116295
# month         0.063757
# year          0.010046
# day_of_month -0.017887
# is_holiday   -0.051698
# day_of_week  -0.068688
# is_weekend   -0.096499
# season       -0.116180
# weather_code -0.166633
# hum          -0.462901

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">9. Plot bike shares over time use lineplot.
# </span>

# %%
plt.figure(figsize=(16, 6))
sns.lineplot(data = df , x="hour" , y="cnt")
# Out:
# <Axes: xlabel='hour', ylabel='cnt'>

# %%
plt.figure(figsize=(16, 4))
sns.lineplot(data = df , x="timestamp" , y="cnt")
# Out:
# <Axes: xlabel='timestamp', ylabel='cnt'>

# %%
df
# Out:
#                       cnt   t1   t2    hum  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0           3.0
# 2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0           1.0
# 2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0           1.0
# 2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0           1.0
# 2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5           1.0
# ...                   ...  ...  ...    ...         ...           ...
# 2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0           3.0
# 2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0           4.0
# 2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0           4.0
# 2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0           4.0
# 2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0           2.0
#
#                      is_holiday  is_weekend  season  year  month  \
# timestamp
# 2015-01-04 00:00:00         0.0         1.0     3.0  2015      1
# 2015-01-04 01:00:00         0.0         1.0     3.0  2015      1
# 2015-01-04 02:00:00         0.0         1.0     3.0  2015      1
# 2015-01-04 03:00:00         0.0         1.0     3.0  2015      1
# 2015-01-04 04:00:00         0.0         1.0     3.0  2015      1
# ...                         ...         ...     ...   ...    ...
# 2017-01-03 19:00:00         0.0         0.0     3.0  2017      1
# 2017-01-03 20:00:00         0.0         0.0     3.0  2017      1
# 2017-01-03 21:00:00         0.0         0.0     3.0  2017      1
# 2017-01-03 22:00:00         0.0         0.0     3.0  2017      1
# 2017-01-03 23:00:00         0.0         0.0     3.0  2017      1
#
#                      day_of_month  day_of_week  hour
# timestamp
# 2015-01-04 00:00:00             4            6     0
# 2015-01-04 01:00:00             4            6     1
# 2015-01-04 02:00:00             4            6     2
# 2015-01-04 03:00:00             4            6     3
# 2015-01-04 04:00:00             4            6     4
# ...                           ...          ...   ...
# 2017-01-03 19:00:00             3            1    19
# 2017-01-03 20:00:00             3            1    20
# 2017-01-03 21:00:00             3            1    21
# 2017-01-03 22:00:00             3            1    22
# 2017-01-03 23:00:00             3            1    23
#
# [17414 rows x 14 columns]

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">10. Plot bike shares by months and year_of_month (use lineplot, pointplot, barplot).
# </span>

# %%
plt.figure(figsize=(16, 4))
sns.lineplot(data = df , x="month" , y="cnt")
# Out:
# <Axes: xlabel='month', ylabel='cnt'>

# %%
plt.figure(figsize=(10, 5))
sns.barplot(x="year", y="cnt", data = df, palette="coolwarm")
plt.show()

# %%
df
# Out:
#                       cnt   t1   t2    hum  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0           3.0
# 2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0           1.0
# 2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0           1.0
# 2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0           1.0
# 2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5           1.0
# ...                   ...  ...  ...    ...         ...           ...
# 2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0           3.0
# 2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0           4.0
# 2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0           4.0
# 2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0           4.0
# 2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0           2.0
#
#                      is_holiday  is_weekend  season  year  month  \
# timestamp
# 2015-01-04 00:00:00         0.0         1.0     3.0  2015      1
# 2015-01-04 01:00:00         0.0         1.0     3.0  2015      1
# 2015-01-04 02:00:00         0.0         1.0     3.0  2015      1
# 2015-01-04 03:00:00         0.0         1.0     3.0  2015      1
# 2015-01-04 04:00:00         0.0         1.0     3.0  2015      1
# ...                         ...         ...     ...   ...    ...
# 2017-01-03 19:00:00         0.0         0.0     3.0  2017      1
# 2017-01-03 20:00:00         0.0         0.0     3.0  2017      1
# 2017-01-03 21:00:00         0.0         0.0     3.0  2017      1
# 2017-01-03 22:00:00         0.0         0.0     3.0  2017      1
# 2017-01-03 23:00:00         0.0         0.0     3.0  2017      1
#
#                      day_of_month  day_of_week  hour
# timestamp
# 2015-01-04 00:00:00             4            6     0
# 2015-01-04 01:00:00             4            6     1
# 2015-01-04 02:00:00             4            6     2
# 2015-01-04 03:00:00             4            6     3
# 2015-01-04 04:00:00             4            6     4
# ...                           ...          ...   ...
# 2017-01-03 19:00:00             3            1    19
# 2017-01-03 20:00:00             3            1    20
# 2017-01-03 21:00:00             3            1    21
# 2017-01-03 22:00:00             3            1    22
# 2017-01-03 23:00:00             3            1    23
#
# [17414 rows x 14 columns]

# %%
plt.figure(figsize=(16, 8))
sns.pointplot(x="month", y="cnt", data=df ) # markers=["o", "s"], linestyles=["-"])

plt.show()

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">11. Plot bike shares by hours on (holidays, weekend, season).
# </span>

# %%
sns.lineplot(data=df , x = "hour" ,y = "cnt" , hue = "is_holiday" )
# Out:
# <Axes: xlabel='hour', ylabel='cnt'>

# %%
sns.barplot(data=df , x = "hour" ,y = "cnt" , hue = "is_weekend" )
# Out:
# <Axes: xlabel='hour', ylabel='cnt'>

# %%
plt.figure(figsize = (16,6))
sns.scatterplot(data=df , x = "hour" ,y = "cnt" , hue = "season" , palette = "viridis")
# Out:
# <Axes: xlabel='hour', ylabel='cnt'>

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red"> 12. Plot bike shares by day of week.
#
# - You may want to see whether it is a holiday or not
# </span>

# %%
Days={0 : "Monday",1 : "Tuesday",2 : "Wednesday",3 : "Thursday",4:"Friday",5:"Saturday",6:"Sunday"}
df["day_of_week"] = df["day_of_week"].map(Days)

# %%
df
# Out:
#                       cnt   t1   t2    hum  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0           3.0
# 2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0           1.0
# 2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0           1.0
# 2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0           1.0
# 2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5           1.0
# ...                   ...  ...  ...    ...         ...           ...
# 2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0           3.0
# 2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0           4.0
# 2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0           4.0
# 2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0           4.0
# 2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0           2.0
#
#                      is_holiday  is_weekend  season  year  month  \
# timestamp
# 2015-01-04 00:00:00         0.0         1.0     3.0  2015      1
# 2015-01-04 01:00:00         0.0         1.0     3.0  2015      1
# 2015-01-04 02:00:00         0.0         1.0     3.0  2015      1
# 2015-01-04 03:00:00         0.0         1.0     3.0  2015      1
# 2015-01-04 04:00:00         0.0         1.0     3.0  2015      1
# ...                         ...         ...     ...   ...    ...
# 2017-01-03 19:00:00         0.0         0.0     3.0  2017      1
# 2017-01-03 20:00:00         0.0         0.0     3.0  2017      1
# 2017-01-03 21:00:00         0.0         0.0     3.0  2017      1
# 2017-01-03 22:00:00         0.0         0.0     3.0  2017      1
# 2017-01-03 23:00:00         0.0         0.0     3.0  2017      1
#
#                      day_of_month day_of_week  hour
# timestamp
# 2015-01-04 00:00:00             4      Sunday     0
# 2015-01-04 01:00:00             4      Sunday     1
# 2015-01-04 02:00:00             4      Sunday     2
# 2015-01-04 03:00:00             4      Sunday     3
# 2015-01-04 04:00:00             4      Sunday     4
# ...                           ...         ...   ...
# 2017-01-03 19:00:00             3     Tuesday    19
# 2017-01-03 20:00:00             3     Tuesday    20
# 2017-01-03 21:00:00             3     Tuesday    21
# 2017-01-03 22:00:00             3     Tuesday    22
# 2017-01-03 23:00:00             3     Tuesday    23
#
# [17414 rows x 14 columns]

# %%
plt.figure(figsize = (16,6))
sns.barplot(data=df , x = "day_of_week" ,y = "cnt" , hue = "is_weekend" )
# Out:
# <Axes: xlabel='day_of_week', ylabel='cnt'>

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red"> 13. Plot bike shares by day of month
# </span>

# %%
plt.figure(figsize = (16,6))
sns.barplot(data=df , x = "day_of_month" ,y = "cnt" )
# Out:
# <Axes: xlabel='day_of_month', ylabel='cnt'>

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red"> 14. Plot bike shares by year
#
# - Plot bike shares on holidays by seasons
# </span>

# %%
plt.figure(figsize = (16,6))
sns.barplot(data=df , x = "year" ,y = "cnt",hue = "season" )
# Out:
# <Axes: xlabel='year', ylabel='cnt'>

# %%
df
# Out:
#                       cnt   t1   t2    hum  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0           3.0
# 2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0           1.0
# 2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0           1.0
# 2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0           1.0
# 2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5           1.0
# ...                   ...  ...  ...    ...         ...           ...
# 2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0           3.0
# 2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0           4.0
# 2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0           4.0
# 2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0           4.0
# 2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0           2.0
#
#                      is_holiday  is_weekend  season  year  month  \
# timestamp
# 2015-01-04 00:00:00         0.0         1.0     3.0  2015      1
# 2015-01-04 01:00:00         0.0         1.0     3.0  2015      1
# 2015-01-04 02:00:00         0.0         1.0     3.0  2015      1
# 2015-01-04 03:00:00         0.0         1.0     3.0  2015      1
# 2015-01-04 04:00:00         0.0         1.0     3.0  2015      1
# ...                         ...         ...     ...   ...    ...
# 2017-01-03 19:00:00         0.0         0.0     3.0  2017      1
# 2017-01-03 20:00:00         0.0         0.0     3.0  2017      1
# 2017-01-03 21:00:00         0.0         0.0     3.0  2017      1
# 2017-01-03 22:00:00         0.0         0.0     3.0  2017      1
# 2017-01-03 23:00:00         0.0         0.0     3.0  2017      1
#
#                      day_of_month day_of_week  hour
# timestamp
# 2015-01-04 00:00:00             4      Sunday     0
# 2015-01-04 01:00:00             4      Sunday     1
# 2015-01-04 02:00:00             4      Sunday     2
# 2015-01-04 03:00:00             4      Sunday     3
# 2015-01-04 04:00:00             4      Sunday     4
# ...                           ...         ...   ...
# 2017-01-03 19:00:00             3     Tuesday    19
# 2017-01-03 20:00:00             3     Tuesday    20
# 2017-01-03 21:00:00             3     Tuesday    21
# 2017-01-03 22:00:00             3     Tuesday    22
# 2017-01-03 23:00:00             3     Tuesday    23
#
# [17414 rows x 14 columns]

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">15. Visualize the distribution of bike shares by weekday/weekend with piechart and barplot
# </span>

# %%
fig, ax = plt.subplots( figsize = (10, 6))
ax = sns.barplot(data = df, x = "is_weekend", y = "cnt");


for bar in ax.patches: 
        ax.annotate( ( "%"+str(round(100*bar.get_height()/len(df["is_weekend"]),1)) +' - '+ str(round(bar.get_height(),1)) ), 
                    (bar.get_x()+0.2 , bar.get_height()+20) ,
                    size=12)

# %%
fig, ax = plt.subplots(figsize=(6,6))

colors_list = ["yellowgreen", "lightskyblue"]
explode_list = [0, 0.1]

ax.pie(df.is_weekend.value_counts().values,
      labels=["weekday", "weekend"],
      labeldistance=0.4,
      autopct="%.1f%%", shadow=True, 
      colors = colors_list, explode=explode_list);

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">16. Plot the distribution of weather code by seasons
# </span>

# %%
fig, ax = plt.subplots(figsize=(10, 6))
sns.kdeplot(x='season', hue='weather_code', data=df, palette='viridis', shade = True)
# Out:
# <Axes: xlabel='season', ylabel='Density'>

# %%
sns.countplot(x='season', hue='weather_code', data=df, palette='viridis')
# Out:
# <Axes: xlabel='season', ylabel='count'>

# %%
Season1 = {0 : "Spring", 1 : "Summer", 2 : "Fall", 3 : "Winter"}
df["season"] = df["season"].map(Season1)

# %%
sns.countplot(x='season', hue='weather_code', data=df, palette='viridis')
# Out:
# <Axes: xlabel='season', ylabel='count'>

# %%
df.sample(10)
# Out:
#                       cnt    t1    t2   hum  wind_speed  weather_code  \
# timestamp
# 2016-05-20 16:00:00  2387  19.0  19.0  49.0        20.5           2.0
# 2015-03-25 00:00:00   145   4.5   3.0  81.0         7.5           1.0
# 2016-06-19 15:00:00  2985  20.0  20.0  58.0        22.0           3.0
# 2016-10-12 14:00:00  1275  15.0  15.0  59.0        24.0           2.0
# 2016-02-21 01:00:00   278  13.0  13.0  77.0        31.5           3.0
# 2015-10-03 04:00:00   171  10.5  10.5  88.0         6.0           3.0
# 2016-01-13 09:00:00  2060   5.0   1.0  73.0        19.5           1.0
# 2016-11-11 15:00:00  1464  10.0   9.0  58.0         8.0           1.0
# 2016-08-17 23:00:00   688  18.0  18.0  75.5         6.5           1.0
# 2015-06-14 03:00:00   288  14.0  14.0  85.0        11.0           1.0
#
#                      is_holiday  is_weekend  season  year  month  \
# timestamp
# 2016-05-20 16:00:00         0.0         0.0  Spring  2016      5
# 2015-03-25 00:00:00         0.0         0.0  Spring  2015      3
# 2016-06-19 15:00:00         0.0         1.0  Summer  2016      6
# 2016-10-12 14:00:00         0.0         0.0    Fall  2016     10
# 2016-02-21 01:00:00         0.0         1.0  Winter  2016      2
# 2015-10-03 04:00:00         0.0         1.0    Fall  2015     10
# 2016-01-13 09:00:00         0.0         0.0  Winter  2016      1
# 2016-11-11 15:00:00         0.0         0.0    Fall  2016     11
# 2016-08-17 23:00:00         0.0         0.0  Summer  2016      8
# 2015-06-14 03:00:00         0.0         1.0  Summer  2015      6
#
#                      day_of_month day_of_week  hour
# timestamp
# 2016-05-20 16:00:00            20      Friday    16
# 2015-03-25 00:00:00            25   Wednesday     0
# 2016-06-19 15:00:00            19      Sunday    15
# 2016-10-12 14:00:00            12   Wednesday    14
# 2016-02-21 01:00:00            21      Sunday     1
# 2015-10-03 04:00:00             3    Saturday     4
# 2016-01-13 09:00:00            13   Wednesday     9
# 2016-11-11 15:00:00            11      Friday    15
# 2016-08-17 23:00:00            17   Wednesday    23
# 2015-06-14 03:00:00            14      Sunday     3

# %% [markdown]
# <div class="alert alert-info alert-info ">
#
# # <span style=" color:red">Conclusions
#
#
#
#
# </span>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <span style=" color:red">Thanks for Attending!..
#
#
# </span>

# %% [markdown]
# # <p style="background-color:green;font-family:newtimeroman;font-size:200%;color:white;text-align:center;border-radius:20px 20px;"><b>EDA & Data Visualization Project</b></p>
# ![](https://www.techproeducation.com/logo/headerlogo.svg)
#
# <b>Yeniliklerden ilk siz haberdar olmak istiyorsanız lütfen bizi takip etmeyi unutmayın </b>[YouTube](https://www.youtube.com/c/techproeducation) | [Instagram](https://www.instagram.com/techproeducation) | [Facebook](https://www.facebook.com/techproeducation) | [Telegram](https://t.me/joinchat/HH2qRvA-ulh4OWbb) | [Whatsapp](https://api.whatsapp.com/send/?phone=%2B15853042959&text&type=phone_number&app_absent=0) | [Linkedin](https://www.linkedin.com/company/techproeducation/mycompany/) |
